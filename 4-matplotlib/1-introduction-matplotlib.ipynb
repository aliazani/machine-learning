# %%
# import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
# create an empty plot
plt.plot()
# Out:
# []

# %%
# use ; and get rid of [] in plot
plt.plot();

# %%
# use plot and plt.show --> it's same as ;
plt.plot()
plt.show()

# %%
# create a plot use y ==> [1, 2, 3, 4]

plt.plot([1, 2, 3, 4])

# %%
# create a plot use y ==> [11, 22, 33, 44] 
# x ==> [1, 2, 3, 4]
x = [1, 2, 3 ,4]
y = [11, 22 ,33, 44]
plt.plot(x, y);

# %%
# 1st method 
# create figure and add_subplot
# and plt.show
fig = plt.figure()
axe = fig.add_subplot()
plt.show(x, y)

# %%
# 2nd method 
# create a figure and add_axes
# axe.plt(x, y) and at last plt.show()
fig = plt.figure()
axe = fig.add_axes([1, 1, 1 ,1])
axe.plot(x, y)
plt.show()

# %%
# 3rd method (recommended)
# fig, axe = plt.subplots()
# axe.plot(x, y); ==> add some data
fig, axe = plt.subplots()
axe.plot(x, y);
# type of fig and axe
type(fig), type(axe)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## matplotlib workflow

# %%
# A matplotlib workflow

# 0. Import and get matplotlib ready
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10,10)) # (width, height)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show
fig.savefig("sample_plot.png")

# %% [markdown]
# ## making figures with numpy arrays
# * line plot
# * bar plot
# * scatter plot
# * histogram plot
# * subplot

# %%
# create some data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# plot the data 
# default plot of matplotlib ==> line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# scatter plot with the same data
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# another scatter plot 
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# make a plot(Bar) from dictionary 
food_prices = {'Pizza': 20, 'Egg': 5, 'Pasta': 15}
fig, ax = plt.subplots()
ax.set(title='Foods price', xlabel='Food name', ylabel='Price')
ax.bar(food_prices.keys(), food_prices.values());

# %%
# crate horizontal bar
fig, ax = plt.subplots()
ax.set(title='Food', xlabel='price', ylabel='food-name')
ax.barh(list(food_prices.keys()), list(food_prices.values()));

# %%
# make some data 
x = np.random.randn(1000)
# create histogram plot
fig, ax = plt.subplots()
ax.hist(x);

# %%
# subplots ==> 2 options
# 1st:
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(10, 5), nrows=2, ncols=2)
# plot to each different axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(food_prices.keys(), food_prices.values())
ax4.hist(np.random.randn(10000));

# %%
# 2nd :
fig, ax = plt.subplots(nrows=2,
                      ncols=2, figsize=(10, 8))
# plot each axis ==> use indexes
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(food_prices.keys(), food_prices.values())
ax[1, 1].hist(np.random.randn(100));

# %% [markdown]
#  ## Plotting from pandas DataFrames

# %%
# import pandas 
import pandas as pd
# read the car sales csv file
car_sales = pd.read_csv('car-sale.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# create a series use np.random.randn(1000) and use index=pd.date_range='1/1/2020' periods=1000
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2020', periods=1000))

# ts.cumsum ==> is sum of columns
new_ts = ts.cumsum()
new_ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('\.00', '',regex=True)
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]', '').astype(int)
car_sales
# Out:
# /tmp/ipykernel_862288/3541590675.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]', '').astype(int)
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# add sales date column 
car_sales['Sales-date'] = pd.date_range('1/1/2020', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales-date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales['Total-sales'] = car_sales['Price'].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales-date  Total-sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# plot the total sales
car_sales.plot(x='Sales-date', y='Total-sales');

# %%
# scatter plot
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
# create some data
x = np.random.rand(10, 4)
x
# Out:
# array([[0.81872107, 0.8963041 , 0.54998475, 0.22217379],
#        [0.96504662, 0.61141342, 0.6366046 , 0.77461853],
#        [0.32074632, 0.07293795, 0.99021036, 0.35420373],
#        [0.05859971, 0.62049942, 0.51820586, 0.83038591],
#        [0.68096107, 0.14895799, 0.80521687, 0.46477768],
#        [0.09611829, 0.67828583, 0.79343378, 0.17731448],
#        [0.76530389, 0.37922344, 0.06996174, 0.95556737],
#        [0.76628956, 0.07631553, 0.29801488, 0.85255981],
#        [0.07385294, 0.95295552, 0.31206974, 0.18344067],
#        [0.90315544, 0.12214992, 0.87506993, 0.38487285]])

# %%
# turn it to dataframe 

df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.818721  0.896304  0.549985  0.222174
# 1  0.965047  0.611413  0.636605  0.774619
# 2  0.320746  0.072938  0.990210  0.354204
# 3  0.058600  0.620499  0.518206  0.830386
# 4  0.680961  0.148958  0.805217  0.464778
# 5  0.096118  0.678286  0.793434  0.177314
# 6  0.765304  0.379223  0.069962  0.955567
# 7  0.766290  0.076316  0.298015  0.852560
# 8  0.073853  0.952956  0.312070  0.183441
# 9  0.903155  0.122150  0.875070  0.384873

# %%
# show the bar graph
df.plot(kind='bar');

# %%
# or 
df.plot.bar();

# %%
# make a bar graph for car_sales
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
# create a histogram graph 
# it's a better way because it has bins
car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales['Odometer (KM)'].plot(kind='hist');

# %%
# use bins  for hist
car_sales['Odometer (KM)'].plot.hist(bins=40);

# %%
# try on another dataset 
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease[:10]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
# create a histogram of age
heart_disease['age'].plot.hist();

# %%
heart_disease['age'].plot.hist(bins=50);

# %%
# have suplots 
heart_disease.plot.hist(subplots=True, figsize=(20, 35));

# %% [markdown]
# ## Plotting with pandas using the OO method

# %%
over_50 = heart_disease[heart_disease['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.size
# Out:
# 2912

# %%
# pyplot method
over_50.plot(kind='scatter', x='age', y='chol', c='target', figsize=(10, 10));

# %%
# OO method mixed with pyplot
fig, ax = plt.subplots(figsize=(10, 10))
over_50.plot(kind='scatter', x='age', y='chol', c='target', ax=ax);
# set the limiter for x
ax.set_xlim([50, 80])
# Out:
# (50.0, 80.0)

# %%
# OO method from scratch
fig, ax = plt.subplots(figsize=(10, 10))
# Customize the plot
ax.set(title='Heart disease and Cholesterol levels', xlabel='Age', ylabel='Cholestrol')
# plot the data
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'],
                c=over_50['target'])
# Add legend
ax.legend(*scatter.legend_elements(), title='Target')
# add a horizontal line
ax.axhline(over_50['chol'].mean(), linestyle='-.');

# %% [markdown]
# ## Adding another plot to existing styled one

# %%
# sharex = True ==> two plots have same x label, so it will be shared for both
fig, ax = plt.subplots(figsize=(10, 10), nrows=2, ncols=1, sharex=True)

# ax[0]
scatter = ax[0].scatter(x=over_50['age'], y=over_50['chol'], c=over_50['target'])

ax[0].set(title="Heart Disease and Cholesterol Levels", ylabel='Cholesterol', )
ax[0].legend(*scatter.legend_elements(), title='Target')
ax[0].axhline(y=over_50["chol"].mean(), color='r', linestyle='--', label="Average")
# ax[1]
scatter = ax[1].scatter(x=over_50['age'], y=over_50['thalach'], c=over_50['target'])

ax[1].set(title='Heart disease and Max heart rate', xlabel='Age', ylabel='max heart-rate')
ax[1].legend(*scatter.legend_elements(), title='Target')
ax[1].axhline(y=over_50['thalach'].mean(), color='g', linestyle='-.', label='Average')


# add a title to figure
fig.suptitle('Heart disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# # Customizing your Plots

# %% [markdown]
# ## Style

# %%
# see the different style
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
# use seaborn style
plt.style.use('seaborn')
car_sales['Price'].plot();
# Out:
# /tmp/ipykernel_862288/911554570.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# use seaborn-white gird
plt.style.use('seaborn-white')
car_sales['Price'].plot()
# Out:
# /tmp/ipykernel_862288/8287495.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
# <Axes: >

# %%
plt.style.use('seaborn')
car_sales.plot(x='Price', y='Odometer (KM)', kind='scatter')
# Out:
# /tmp/ipykernel_862288/1597790711.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: xlabel='Price', ylabel='Odometer (KM)'>

# %%
# use ggplot style 
plt.style.use('ggplot')
car_sales['Price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Changing the title, legend and axis

# %%
# create some data 
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.71426018,  1.31661282, -0.58547374,  0.06344618],
#        [-1.3876534 , -0.27169781,  0.85655099,  1.2704174 ],
#        [ 1.36212932, -0.81979385, -0.62912891,  1.48382965],
#        [ 1.04252633, -0.39056764, -0.56689329,  1.83131593],
#        [-0.12132556,  0.7897839 , -1.43590715,  0.70522853],
#        [ 1.22567701,  0.2949296 ,  0.44980078,  1.37688127],
#        [ 0.25440444, -1.44850197,  0.67581857, -0.11117001],
#        [ 0.08577988, -1.20043224,  0.06736765, -0.13389145],
#        [ 0.15916058, -0.18219232, -0.34829905,  0.17839706],
#        [-0.4760146 , -0.8341032 , -0.6986123 ,  0.75690917]])

# %%
# create a dataframe
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.714260  1.316613 -0.585474  0.063446
# 1 -1.387653 -0.271698  0.856551  1.270417
# 2  1.362129 -0.819794 -0.629129  1.483830
# 3  1.042526 -0.390568 -0.566893  1.831316
# 4 -0.121326  0.789784 -1.435907  0.705229
# 5  1.225677  0.294930  0.449801  1.376881
# 6  0.254404 -1.448502  0.675819 -0.111170
# 7  0.085780 -1.200432  0.067368 -0.133891
# 8  0.159161 -0.182192 -0.348299  0.178397
# 9 -0.476015 -0.834103 -0.698612  0.756909

# %%
ax = df.plot(kind='bar');

# %%
ax = df.plot(kind='bar')
# create label and title
ax.set(title='Random bar graph of the dataframe', xlabel='row number',
        ylabel='Random number')
# create legend
ax.legend().set_visible(True)

# %% [markdown]
# ## Changing the cmap

# %%
# Change the style of plots
plt.style.use('seaborn-whitegrid')
# set the fig and ax
fig, ax = plt.subplots(figsize=(10, 10))
# set plot
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], 
                     c=over_50['target'])
# set title and labels
ax.set(title="Heart disease and cholesterol level", xlabel="Age", ylabel="Cholesterol")
# set legend
ax.legend(*scatter.legend_elements(), title='Target')
# add axhline
ax.axhline(over_50['chol'].mean(), linestyle='--', c='r');
# Out:
# /tmp/ipykernel_862288/3414430521.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Change the style of plots
plt.style.use('seaborn-whitegrid')
# set the fig and ax
fig, ax = plt.subplots(figsize=(10, 10))
# set plot
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], 
                     c=over_50['target'], cmap='winter')
# set title and labels
ax.set(title="Heart disease and cholesterol level", xlabel="Age",
       ylabel="Cholesterol")
# set legend
ax.legend(*scatter.legend_elements(), title='Target')
# add axhline
ax.axhline(over_50['chol'].mean(), linestyle='--', c='r');
# Out:
# /tmp/ipykernel_862288/2323481554.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Change the style of plots
plt.style.use('seaborn-whitegrid')
# set the fig and ax
fig, ax = plt.subplots(figsize=(10, 10))
# set plot
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], 
                     c=over_50['target'], cmap='plasma')
# set title and labels
ax.set(title="Heart disease and cholesterol level", xlabel="Age",
       ylabel="Cholesterol")
# set legend
ax.legend(*scatter.legend_elements(), title='Target')
# add axhline
ax.axhline(over_50['chol'].mean(), linestyle='--', c='r');
# Out:
# /tmp/ipykernel_862288/4253128235.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Change the style of plots
plt.style.use('seaborn-whitegrid')
# set the fig and ax
fig, ax = plt.subplots(figsize=(10, 10))
# set plot
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], 
                     c=over_50['target'], cmap='spring')
# set title and labels
ax.set(title="Heart disease and cholesterol level", xlabel="Age",
       ylabel="Cholesterol")
# set legend
ax.legend(*scatter.legend_elements(), title='Target')
# add axhline
ax.axhline(over_50['chol'].mean(), linestyle='--', c='r');
# Out:
# /tmp/ipykernel_862288/895458636.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Change the style of plots
plt.style.use('seaborn-whitegrid')
# set the fig and ax
fig, ax = plt.subplots(figsize=(10, 10))
# set plot
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], 
                     c=over_50['target'], cmap='coolwarm')
# set title and labels
ax.set(title="Heart disease and cholesterol level", xlabel="Age",
       ylabel="Cholesterol")
# set legend
ax.legend(*scatter.legend_elements(), title='Target')
# add axhline
ax.axhline(over_50['chol'].mean(), linestyle='--', c='r');
# Out:
# /tmp/ipykernel_862288/3961567.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Change the style of plots
plt.style.use('seaborn-whitegrid')
# set the fig and ax
fig, ax = plt.subplots(figsize=(10, 10))
# set plot
scatter = ax.scatter(x=over_50['age'], y=over_50['chol'], 
                     c=over_50['target'], cmap='GnBu')
# set title and labels
ax.set(title="Heart disease and cholesterol level", xlabel="Age",
       ylabel="Cholesterol")
# set legend
ax.legend(*scatter.legend_elements(), title='Target')
# add axhline
ax.axhline(over_50['chol'].mean(), linestyle='--', c='r');
# Out:
# /tmp/ipykernel_862288/1213101098.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# customizing the x and y limitation
# sharex = True ==> two plots have same x label, so it will be shared for both
fig, ax = plt.subplots(figsize=(10, 10), nrows=2, ncols=1, sharex=True)

# ax[0]
scatter = ax[0].scatter(x=over_50['age'], y=over_50['chol'],
                        c=over_50['target'], cmap='winter')
# add title and labels
ax[0].set(title="Heart Disease and Cholesterol Levels", ylabel='Cholesterol', )
# set xlimiter
ax[0].set_xlim([50, 80])
# add legend
ax[0].legend(*scatter.legend_elements(), title='Target')
# add line
ax[0].axhline(y=over_50["chol"].mean(), color='r', linestyle='--', label="Average")

# ax[1]
scatter = ax[1].scatter(x=over_50['age'], y=over_50['thalach'],
                        c=over_50['target'], cmap='spring')
# add title and labels
ax[1].set(title='Heart disease and Max heart rate', xlabel='Age', ylabel='max heart-rate')
# add legend
ax[1].legend(*scatter.legend_elements(), title='Target')
# add hline
ax[1].axhline(y=over_50['thalach'].mean(), color='b', linestyle='-.', label='Average')
# set y limiter
ax[1].set_ylim([50, 200])

# add a title to figure
fig.suptitle('Heart disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# # saving the plots

# %%
# last figure or canvas
fig

# %%
# Check the supported filetypes
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
# save the figure 
fig.savefig('hear_disease_analysis.png')
